# %%
from drone_range_assignment import Solver, Instance, Point

# %%
#instance = Instance([Point(0,0), Point(5, 3), Point(10, 4), Point(20, 20)], 1)
solutions = []
for n in range(4):
    instance = Instance([Point(0,0), Point(5, 10), Point(10,0)], n)
    model = Solver(instance)
    solution = model.solve()
    solutions.append(solution)
    assert solution.is_feasible(0.01)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-02-16
# Set parameter LazyConstraints to value 1
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD Ryzen 7 5700X 8-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 7 rows, 9 columns and 18 nonzeros
# Model fingerprint: 0x00c26412
# Variable types: 3 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [3e+00, 3e+00]
# Found heuristic solution: objective 375.0000000
# Presolve time: 0.00s
# Presolved: 7 rows, 9 columns, 20 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 1.875000e+02, 9 iterations, 0.00 seconds (0.00 work units)
#
# ...

# %%
import matplotlib.pyplot as plt
from drone_range_assignment import plot
fix, axes = plt.subplots(1,len(solutions), figsize = (15,4))
for i in range(len(solutions)):
    ax = axes[i]
    solution = solutions[i]
    plot(ax, solution)
    ax.set_title(f"{i} drone(s) \nPower: {round(solution.objective(),2)}")
plt.tight_layout()
plt.savefig("../docs/figures/example.png")
plt.show()
