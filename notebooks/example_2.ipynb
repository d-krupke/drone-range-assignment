# %%
from drone_range_assignment import Solver, Instance, Point

# %%
instance = Instance([Point(0,0), Point(5, 3), Point(10, 4), Point(20, 20), Point(0, 20)], 2)
solutions = []
model = Solver(instance)
solution = model.solve()
assert solution.is_feasible(0.001)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-02-16
# Set parameter LazyConstraints to value 1
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD Ryzen 7 5700X 8-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 65 rows, 86 columns and 182 nonzeros
# Model fingerprint: 0x9342a0e5
# Model has 11 quadratic constraints
# Variable types: 44 continuous, 42 integer (42 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [3e+00, 8e+02]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 59 rows, 80 columns, 183 nonzeros
# Presolved model has 11 quadratic constraint(s)
# Variable types: 38 continuous, 42 integer (42 binary)
#
# Root relaxation: objective 0.000000e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    5          -    0.00000      -     -    0s
#      0     0    0.00000    0    7          -    0.00000      -     -    0s
#      0     0    0.00000    0    9          -    0.00000      -     -    0s
#      0     0    0.00000    0    9          -    0.00000      -     -    0s
#      0     0    0.00000    0    9          -    0.00000      -     -    0s
#      0     0    0.00000    0    4          -    0.00000      -     -    0s
#      0     0    0.00000    0    9          -    0.00000      -     -    0s
#      0     0    0.00000    0    7          -    0.00000      -     -    0s
#      0     0    0.00000    0    8          -    0.00000      -     -    0s
#      0     0    0.00000    0    8          -    0.00000      -     -    0s
#      0     0    0.00000    0    8          -    0.00000      -     -    0s
#      0     0    0.00000    0    8          -    0.00000      -     -    0s
#      0     0    0.00000    0    8          -    0.00000      -     -    0s
# H    0     0                    1074.4544411    0.00000   100%     -    0s
#      0     2    0.00000    0    8 1074.45444    0.00000   100%     -    0s
#   4451  2677  435.99977   37   16 1074.45444  253.03721  76.4%  16.3    8s
#   5567  3210  404.09236   36   16 1074.45444  253.03721  76.4%  18.0   10s
# * 5979  2924              54     561.9999874  253.03721  55.0%  18.2   10s
# H 6127  2741                     534.9999642  253.03721  52.7%  18.2   10s
# H 6182  2606                     518.9951229  253.03721  51.2%  18.2   10s
#  13046     1  458.45197   57    -  518.99512  458.45197  11.7%  17.3   15s
# *13087    36              54     516.9999905  458.45197  11.3%  17.2   15s
# *13097    43              53     516.9999790  458.45197  11.3%  17.2   15s
# *13284    43              48     510.9999705  458.45296  10.3%  17.1   15s
# *13340    38              52     492.0936986  458.45296  6.84%  17.0   15s
# *13395     8              53     477.7359307  458.45315  4.04%  17.0   15s
# *13397     4              56     458.9542238  458.45315  0.11%  17.0   15s
# *13427     1              51     458.4533566  458.45329  0.00%  17.0   15s
#
# Cutting planes:
#   Lazy constraints: 21
#
# Explored 13430 nodes (228243 simplex iterations) in 15.24 seconds (14.48 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 458.453 458.954 477.736 ... 562
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (1.3540e-05) exceeds tolerance
# Best objective 4.584533565896e+02, best bound 4.584532914921e+02, gap 0.0000%
#
# User-callback calls 28800, time in user-callback 0.06 sec

# %%
import matplotlib.pyplot as plt
from drone_range_assignment import plot
solutions = [solution]
fix, ax = plt.subplots(1,1)
plot(ax, solution)
ax.set_title(f"{len(instance.drones)} drone(s) \nPower: {round(solution.objective(),2)}")
plt.tight_layout()
plt.show()
